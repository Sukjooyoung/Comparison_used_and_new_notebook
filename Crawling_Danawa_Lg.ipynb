# %%
from selenium import webdriver

# %%
driver = webdriver.Firefox()
driver.get("http://www.naver.com/")

# %% [markdown]
# # 다나와 사이트 크롤링

# %%
driver.get("http://prod.danawa.com/list/?cate=112758&searchOption=btnAllOptUse=true/searchMaker%5B%5D=702/innerSearchKeyword=")

# %%
import pandas as pd
import pickle

# %%
post= driver.find_elements_by_css_selector("#productListArea")[0].find_elements_by_css_selector("div.main_prodlist.main_prodlist_list")[0]

# %%
df = pd.DataFrame(columns=["CPU" , "CPU2", "CPU3" , "Ram" , "Memory" , "Weight" , "Size", "Price"])

# %%
import re
def crawling():
    for post_element in post_elements:
        spec = post_element.find_element_by_css_selector("div.spec_list").text.strip()
        price = post_element.find_element_by_css_selector("div.prod_pricelist").text.strip()
        cpu_pattern = re.compile("코어i[0-9]{1}")
        cpu2_pattern = re.compile("[0-9]{1}세대")
        cpu3_pattern = re.compile("[0-9 ]{4}[A-Z]{1,2}")
        ram_pattern = re.compile(" [0-9]{1,2}GB")
        memory_pattern = re.compile("SSD / [0-9]{3}GB")
        weight_pattern = re.compile("[0-9]?[.]?[0-9]{1,3}[ K]{1,2}?g")
        size_pattern = re.compile("[]?{1,2}[0-9]{1,2}[.]?[0-9 ]{1,3}인치")
        price_pattern = re.compile("[0-9]?[,]?[0-9]{2,3}[,][0-9]{3}원")

        cpu = cpu_pattern.findall(spec)[0]
        cpu2 = cpu2_pattern.findall(spec)[0]
        cpu3 = cpu3_pattern.findall(spec)[0]
        ram = ram_pattern.findall(spec)[0]
        memory = memory_pattern.findall(spec)
        if memory:
            memory = memory_pattern.findall(spec)[0]
        else:
            memory = "HDD"

        weight = weight_pattern.findall(spec)
        if weight:
            weight = weight_pattern.findall(spec)[0]
        else:
            weight = "None"
        size = size_pattern.findall(spec)
        if size:
            size = size_pattern.findall(spec)[0]
        else:
            size = "None"
        
        try:
            price = price_pattern.findall(price)[0]

            data = {"CPU" : cpu , "CPU2": cpu2 , "CPU3":cpu3 , "Ram" : ram , "Memory" : memory , "Weight" : weight , "Size":size , "Price" : price}
            df.loc[len(df)] = data

        except:
            pass

    return df

# %%
url = driver.find_elements_by_css_selector("div.number_wrap")[0].find_elements_by_css_selector("a")[0].get_attribute("href")

# %%
driver.get(url)

# %%
import time
for i in range(1,18):
    time.sleep(3)
    driver.execute_script("movePage({i})".format(i = i))
    time.sleep(3)
    post= driver.find_elements_by_css_selector("#productListArea")[0].find_elements_by_css_selector("div.main_prodlist.main_prodlist_list")[0]
    time.sleep(3.5)
    post_elements = post.find_elements_by_css_selector("div.prod_main_info")
    time.sleep(3)
    crawling()

# %%
df
# Out:
#       CPU CPU2    CPU3   Ram       Memory   Weight    Size       Price
# 0    코어i5  6세대   6200U   8GB          HDD     None  15.6인치  1,195,000원
# 1    코어i5  6세대   6200U   8GB          HDD   1.89Kg  15.6인치    875,000원
# 2    코어i3  6세대   6100U   8GB          HDD   1.79Kg  15.6인치    633,000원
# 3    코어i5  6세대   6200U   8GB          HDD     None    14인치  1,016,000원
# 4    코어i7  6세대   6500U   8GB          HDD     None  15.6인치  1,359,000원
# 5    코어i3  6세대   6100U   4GB          HDD   1.79Kg  15.6인치    542,000원
# 6    코어i5  5세대   5200U   8GB          HDD     None  13.3인치    882,000원
# 7    코어i5  6세대   6200U   8GB          HDD     None    14인치  1,229,000원
# 8    코어i5  6세대   6200U   4GB          HDD   2.11Kg  15.6인치    759,000원
# 9    코어i3  6세대   6100U   8GB          HDD     None    14인치    895,000원
# 10   코어i5  6세대   6200U   8GB          HDD     None  15.6인치  1,285,000원
# 11   코어i5  6세대   6200U   8GB          HDD   1.79Kg  15.6인치  1,119,000원
# 12   코어i3  6세대   6100U   8GB          HDD     None  15.6인치    966,000원
# 13   코어i5  6세대   6200U   8GB          HDD   1.79Kg  15.6인치    730,000원
# 14   코어i5  5세대   5200U   8GB  SSD / 128GB   1.05Kg  11.6인치    831,000원
# 15   코어i5  6세대   6200U   8GB          HDD   1.79Kg  15.6인치    663,000원
# 16   코어i3  5세대   5005U   4GB  SSD / 256GB     None  13.3인치    790,000원
# 17   코어i5  5세대   5200U   8GB          HDD   1.39Kg  15.6인치    914,000원
# 18   코어i3  5세대   5005U   4GB  SSD / 128GB   2.11Kg  15.6인치    626,000원
# 19   코어i3  6세대   6100U   4GB          HDD     None  15.6인치    955,000원
# 20   코어i7  6세대   6500U   8GB          HDD     None  15.6인치  1,646,000원
# 21   코어i5  6세대   6200U   8GB          HDD   1.89Kg  15.6인치  1,050,000원
# 22   코어i3  5세대   5005U   8GB          HDD     None  13.3인치    768,000원
# 23   코어i5  6세대   6200U   8GB          HDD     None  15.6인치  1,260,000원
# 24   코어i3  5세대   5005U   4GB          HDD     None    14인치    910,000원
# 25   코어i5  6세대   6200U   8GB          HDD     None  15.6인치  1,234,000원
# 26   코어i7  6세대   6500U   8GB          HDD   1.89Kg  15.6인치  1,113,000원
# 27   코어i7  6세대   6500U   8GB          HDD   1.89Kg  15.6인치  1,438,000원
# 28   코어i5  6세대   6200U   8GB          HDD     None    14인치  1,073,000원
# 29   코어i5  6세대   6200U   4GB  SSD / 128GB   2.11Kg  15.6인치    856,000원
# ..    ...  ...     ...   ...          ...      ...     ...         ...
# 455  코어i7  5세대   5500U   8GB          HDD     None    14인치  1,488,000원
# 456  코어i5  5세대   5200U   4GB          HDD     None    14인치  1,123,000원
# 457  코어i7  5세대   5500U   8GB          HDD     None    14인치  1,360,000원
# 458  코어i5  5세대   5200U   8GB          HDD   1.39Kg  15.6인치  1,219,000원
# 459  코어i7  5세대   5500U   8GB          HDD     None    14인치  1,439,000원
# 460  코어i3  5세대   5005U   8GB          HDD     None    14인치  1,134,000원
# 461  코어i5  5세대   5200U   8GB          HDD   1.39Kg  15.6인치  1,401,000원
# 462  코어i5  5세대   5200U   8GB          HDD     None    14인치  1,380,000원
# 463  코어i7  4세대  4712MQ   4GB  SSD / 128GB    2.1Kg  15.6인치  1,350,000원
# 464  코어i5  5세대   5200U   4GB          HDD   1.39Kg  15.6인치  1,290,000원
# 465  코어i5  5세대   5200U   8GB          HDD     None    14인치  1,369,000원
# 466  코어i5  4세대   4210U   4GB  SSD / 128GB   1.95Kg  15.6인치    920,000원
# 467  코어i7  4세대  4712MQ   4GB          HDD    2.1Kg  15.6인치  1,388,000원
# 468  코어i5  4세대   4300U   4GB          HDD    1.6Kg    14인치  1,079,000원
# 469  코어i7  4세대  4712MQ   4GB          HDD    2.1Kg  15.6인치  1,315,000원
# 470  코어i5  4세대   4310M   4GB          HDD    2.1Kg  15.6인치  1,084,000원
# 471  코어i5  4세대   4200U   8GB  SSD / 128GB     None  13.3인치  1,122,890원
# 472  코어i5  4세대   4200M   8GB          HDD   2.35Kg  15.6인치  1,299,000원
# 473  코어i7  4세대  4702MQ   4GB  SSD / 128GB   2.35Kg  15.6인치  1,374,000원
# 474  코어i7  4세대  4702MQ   4GB          HDD   2.35Kg  15.6인치  1,314,000원
# 475  코어i5  4세대   4200U   4GB  SSD / 128GB   1.85Kg  15.6인치    954,000원
# 476  코어i5  4세대   4200U   4GB          HDD    1.6Kg    14인치  1,176,600원
# 477  코어i7  4세대  4702MQ   4GB  SSD / 120GB   2.35Kg  15.6인치  1,389,000원
# 478  코어i5  4세대   4200U   4GB  SSD / 128GB   1.95Kg  15.6인치  1,089,850원
# 479  코어i5  3세대   3230M   4GB          HDD  2.43 Kg  15.6인치    938,780원
# 480  코어i5  3세대   3317U   4GB  SSD / 128GB   1.21Kg  13.3인치  1,247,040원
# 481  코어i5  5세대   5200U   8GB          HDD     None    14인치  1,539,000원
# 482  코어i3  5세대   5005U   8GB          HDD     None    14인치  1,088,000원
# 483  코어i5  5세대   5200U   4GB          HDD     None    14인치  1,199,000원
# 484  코어i7  4세대  4712MQ   4GB  SSD / 128GB    2.1Kg  15.6인치  1,240,000원
#
# [485 rows x 8 columns]

# %%
df.to_pickle("DanawaLg.pkl")

# %%
pickle.load(open("DanawaLg.pkl","rb"))
# Out:
#       CPU CPU2    CPU3   Ram       Memory   Weight    Size       Price
# 0    코어i5  6세대   6200U   8GB          HDD     None  15.6인치  1,195,000원
# 1    코어i5  6세대   6200U   8GB          HDD   1.89Kg  15.6인치    875,000원
# 2    코어i3  6세대   6100U   8GB          HDD   1.79Kg  15.6인치    633,000원
# 3    코어i5  6세대   6200U   8GB          HDD     None    14인치  1,016,000원
# 4    코어i7  6세대   6500U   8GB          HDD     None  15.6인치  1,359,000원
# 5    코어i3  6세대   6100U   4GB          HDD   1.79Kg  15.6인치    542,000원
# 6    코어i5  5세대   5200U   8GB          HDD     None  13.3인치    882,000원
# 7    코어i5  6세대   6200U   8GB          HDD     None    14인치  1,229,000원
# 8    코어i5  6세대   6200U   4GB          HDD   2.11Kg  15.6인치    759,000원
# 9    코어i3  6세대   6100U   8GB          HDD     None    14인치    895,000원
# 10   코어i5  6세대   6200U   8GB          HDD     None  15.6인치  1,285,000원
# 11   코어i5  6세대   6200U   8GB          HDD   1.79Kg  15.6인치  1,119,000원
# 12   코어i3  6세대   6100U   8GB          HDD     None  15.6인치    966,000원
# 13   코어i5  6세대   6200U   8GB          HDD   1.79Kg  15.6인치    730,000원
# 14   코어i5  5세대   5200U   8GB  SSD / 128GB   1.05Kg  11.6인치    831,000원
# 15   코어i5  6세대   6200U   8GB          HDD   1.79Kg  15.6인치    663,000원
# 16   코어i3  5세대   5005U   4GB  SSD / 256GB     None  13.3인치    790,000원
# 17   코어i5  5세대   5200U   8GB          HDD   1.39Kg  15.6인치    914,000원
# 18   코어i3  5세대   5005U   4GB  SSD / 128GB   2.11Kg  15.6인치    626,000원
# 19   코어i3  6세대   6100U   4GB          HDD     None  15.6인치    955,000원
# 20   코어i7  6세대   6500U   8GB          HDD     None  15.6인치  1,646,000원
# 21   코어i5  6세대   6200U   8GB          HDD   1.89Kg  15.6인치  1,050,000원
# 22   코어i3  5세대   5005U   8GB          HDD     None  13.3인치    768,000원
# 23   코어i5  6세대   6200U   8GB          HDD     None  15.6인치  1,260,000원
# 24   코어i3  5세대   5005U   4GB          HDD     None    14인치    910,000원
# 25   코어i5  6세대   6200U   8GB          HDD     None  15.6인치  1,234,000원
# 26   코어i7  6세대   6500U   8GB          HDD   1.89Kg  15.6인치  1,113,000원
# 27   코어i7  6세대   6500U   8GB          HDD   1.89Kg  15.6인치  1,438,000원
# 28   코어i5  6세대   6200U   8GB          HDD     None    14인치  1,073,000원
# 29   코어i5  6세대   6200U   4GB  SSD / 128GB   2.11Kg  15.6인치    856,000원
# ..    ...  ...     ...   ...          ...      ...     ...         ...
# 455  코어i7  5세대   5500U   8GB          HDD     None    14인치  1,488,000원
# 456  코어i5  5세대   5200U   4GB          HDD     None    14인치  1,123,000원
# 457  코어i7  5세대   5500U   8GB          HDD     None    14인치  1,360,000원
# 458  코어i5  5세대   5200U   8GB          HDD   1.39Kg  15.6인치  1,219,000원
# 459  코어i7  5세대   5500U   8GB          HDD     None    14인치  1,439,000원
# 460  코어i3  5세대   5005U   8GB          HDD     None    14인치  1,134,000원
# 461  코어i5  5세대   5200U   8GB          HDD   1.39Kg  15.6인치  1,401,000원
# 462  코어i5  5세대   5200U   8GB          HDD     None    14인치  1,380,000원
# 463  코어i7  4세대  4712MQ   4GB  SSD / 128GB    2.1Kg  15.6인치  1,350,000원
# 464  코어i5  5세대   5200U   4GB          HDD   1.39Kg  15.6인치  1,290,000원
# 465  코어i5  5세대   5200U   8GB          HDD     None    14인치  1,369,000원
# 466  코어i5  4세대   4210U   4GB  SSD / 128GB   1.95Kg  15.6인치    920,000원
# 467  코어i7  4세대  4712MQ   4GB          HDD    2.1Kg  15.6인치  1,388,000원
# 468  코어i5  4세대   4300U   4GB          HDD    1.6Kg    14인치  1,079,000원
# 469  코어i7  4세대  4712MQ   4GB          HDD    2.1Kg  15.6인치  1,315,000원
# 470  코어i5  4세대   4310M   4GB          HDD    2.1Kg  15.6인치  1,084,000원
# 471  코어i5  4세대   4200U   8GB  SSD / 128GB     None  13.3인치  1,122,890원
# 472  코어i5  4세대   4200M   8GB          HDD   2.35Kg  15.6인치  1,299,000원
# 473  코어i7  4세대  4702MQ   4GB  SSD / 128GB   2.35Kg  15.6인치  1,374,000원
# 474  코어i7  4세대  4702MQ   4GB          HDD   2.35Kg  15.6인치  1,314,000원
# 475  코어i5  4세대   4200U   4GB  SSD / 128GB   1.85Kg  15.6인치    954,000원
# 476  코어i5  4세대   4200U   4GB          HDD    1.6Kg    14인치  1,176,600원
# 477  코어i7  4세대  4702MQ   4GB  SSD / 120GB   2.35Kg  15.6인치  1,389,000원
# 478  코어i5  4세대   4200U   4GB  SSD / 128GB   1.95Kg  15.6인치  1,089,850원
# 479  코어i5  3세대   3230M   4GB          HDD  2.43 Kg  15.6인치    938,780원
# 480  코어i5  3세대   3317U   4GB  SSD / 128GB   1.21Kg  13.3인치  1,247,040원
# 481  코어i5  5세대   5200U   8GB          HDD     None    14인치  1,539,000원
# 482  코어i3  5세대   5005U   8GB          HDD     None    14인치  1,088,000원
# 483  코어i5  5세대   5200U   4GB          HDD     None    14인치  1,199,000원
# 484  코어i7  4세대  4712MQ   4GB  SSD / 128GB    2.1Kg  15.6인치  1,240,000원
#
# [485 rows x 8 columns]
